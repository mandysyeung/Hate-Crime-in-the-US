# %%
import quandl
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import statsmodels.api as sm # Using .api imports the public access version of statsmodels, which is a library that handles 
# statistical models.
import os
import warnings # This is a library that handles warnings.

warnings.filterwarnings("ignore") # Disable deprecation warnings that could indicate, for instance, a suspended library or 
# feature. These are more relevant to developers and very seldom to analysts.

plt.style.use('fivethirtyeight') # This is a styling option for how your plots will appear. More examples here:
# https://matplotlib.org/3.2.1/tutorials/introductory/customizing.html
# https://matplotlib.org/3.1.0/gallery/style_sheets/fivethirtyeight.html

# %%
# %matplotlib inline

# %%
#Define path
path = r'C:\Users\msyeu\Hate Crime Analysis'

# %%
#Import Data
df = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'hate_crime_wrangled.csv'))

# %%
df.head()
# Out:
#    Unnamed: 0  INCIDENT_ID  DATA_YEAR        ORI PUB_AGENCY_NAME  \
# 0           0         3015       1991  AR0040200          Rogers
# 1           1         3016       1991  AR0290100            Hope
# 2           2           43       1991  AR0350100      Pine Bluff
# 3           3           44       1991  AR0350100      Pine Bluff
# 4           4         3017       1991  AR0350100      Pine Bluff
#
#   AGENCY_TYPE_NAME STATE_ABBR STATE_NAME       DIVISION_NAME REGION_NAME  ...  \
# 0             City         AR   Arkansas  West South Central       South  ...
# 1             City         AR   Arkansas  West South Central       South  ...
# 2             City         AR   Arkansas  West South Central       South  ...
# 3             City         AR   Arkansas  West South Central       South  ...
# 4             City         AR   Arkansas  West South Central       South  ...
#
#   TOTAL_OFFENDER_COUNT              OFFENDER_RACE VICTIM_COUNT  \
# 0                    1                      White            1
# 1                    1  Black or African American            1
# 2                    1  Black or African American            1
# 3                    1  Black or African American            2
# 4                    1  Black or African American            1
#
#                                         OFFENSE_NAME TOTAL_INDIVIDUAL_VICTIMS  \
# 0                                       Intimidation                      1.0
# 1                                     Simple Assault                      1.0
# 2                                 Aggravated Assault                      1.0
# 3  Aggravated Assault;Destruction/Damage/Vandalis...                      1.0
# 4                                 Aggravated Assault                      1.0
#
#                         LOCATION_NAME                       BIAS_DESC  \
# 0  Highway/Road/Alley/Street/Sidewalk  Anti-Black or African American
# 1  Highway/Road/Alley/Street/Sidewalk                      Anti-White
# 2                      Residence/Home  Anti-Black or African American
# 3  Highway/Road/Alley/Street/Sidewalk                      Anti-White
# 4                 Service/Gas Station                      Anti-White
#
#    VICTIM_TYPES MULTIPLE_OFFENSE MULTIPLE_BIAS
# 0    Individual                S             S
# 1    Individual                S             S
# 2    Individual                S             S
# 3    Individual                M             S
# 4    Individual                S             S
#
# [5 rows x 23 columns]

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#    INCIDENT_ID  DATA_YEAR        ORI PUB_AGENCY_NAME AGENCY_TYPE_NAME  \
# 0         3015       1991  AR0040200          Rogers             City
# 1         3016       1991  AR0290100            Hope             City
# 2           43       1991  AR0350100      Pine Bluff             City
# 3           44       1991  AR0350100      Pine Bluff             City
# 4         3017       1991  AR0350100      Pine Bluff             City
#
#   STATE_ABBR STATE_NAME       DIVISION_NAME REGION_NAME POPULATION_GROUP_CODE  \
# 0         AR   Arkansas  West South Central       South                     5
# 1         AR   Arkansas  West South Central       South                     6
# 2         AR   Arkansas  West South Central       South                     3
# 3         AR   Arkansas  West South Central       South                     3
# 4         AR   Arkansas  West South Central       South                     3
#
#    ... TOTAL_OFFENDER_COUNT              OFFENDER_RACE  VICTIM_COUNT  \
# 0  ...                    1                      White             1
# 1  ...                    1  Black or African American             1
# 2  ...                    1  Black or African American             1
# 3  ...                    1  Black or African American             2
# 4  ...                    1  Black or African American             1
#
#                                         OFFENSE_NAME  \
# 0                                       Intimidation
# 1                                     Simple Assault
# 2                                 Aggravated Assault
# 3  Aggravated Assault;Destruction/Damage/Vandalis...
# 4                                 Aggravated Assault
#
#    TOTAL_INDIVIDUAL_VICTIMS                       LOCATION_NAME  \
# 0                       1.0  Highway/Road/Alley/Street/Sidewalk
# 1                       1.0  Highway/Road/Alley/Street/Sidewalk
# 2                       1.0                      Residence/Home
# 3                       1.0  Highway/Road/Alley/Street/Sidewalk
# 4                       1.0                 Service/Gas Station
#
#                         BIAS_DESC VICTIM_TYPES MULTIPLE_OFFENSE MULTIPLE_BIAS
# 0  Anti-Black or African American   Individual                S             S
# 1                      Anti-White   Individual                S             S
# 2  Anti-Black or African American   Individual                S             S
# 3                      Anti-White   Individual                M             S
# 4                      Anti-White   Individual                S             S
#
# [5 rows x 22 columns]

# %%
# Drop unnecessary columns
df = df.drop(['INCIDENT_ID', 'ORI', 'PUB_AGENCY_NAME', 'AGENCY_TYPE_NAME', 'DIVISION_NAME', 'POPULATION_GROUP_CODE', 'POPULATION_GROUP_DESC', 'LOCATION_NAME', 'VICTIM_TYPES', 'MULTIPLE_OFFENSE', 'MULTIPLE_BIAS'],axis = 1)

# %%
# Renaming columns 
new_names = {'DATA_YEAR':'incident_year',
             'STATE_ABBR':'state_abbr',
             'STATE_NAME':'state_name',
             'REGION_NAME':'region_name',
             'INCIDENT_DATE':'incident_date',
             'TOTAL_OFFENDER_COUNT':'offender_count',
             'OFFENDER_RACE':'offender_race',
             'VICTIM_COUNT':'victim_count',
             'OFFENSE_NAME':'offense_type',
             'TOTAL_INDIVIDUAL_VICTIMS':'total_individual_victims',
             'BIAS_DESC':'prejudice'}

df.rename(columns=new_names,inplace=True)

# %%
df.head()
# Out:
#    incident_year state_abbr state_name region_name incident_date  \
# 0           1991         AR   Arkansas       South     31-AUG-91
# 1           1991         AR   Arkansas       South     19-SEP-91
# 2           1991         AR   Arkansas       South     04-JUL-91
# 3           1991         AR   Arkansas       South     24-DEC-91
# 4           1991         AR   Arkansas       South     23-DEC-91
#
#    offender_count              offender_race  victim_count  \
# 0               1                      White             1
# 1               1  Black or African American             1
# 2               1  Black or African American             1
# 3               1  Black or African American             2
# 4               1  Black or African American             1
#
#                                         offense_type  \
# 0                                       Intimidation
# 1                                     Simple Assault
# 2                                 Aggravated Assault
# 3  Aggravated Assault;Destruction/Damage/Vandalis...
# 4                                 Aggravated Assault
#
#    total_individual_victims                       prejudice
# 0                       1.0  Anti-Black or African American
# 1                       1.0                      Anti-White
# 2                       1.0  Anti-Black or African American
# 3                       1.0                      Anti-White
# 4                       1.0                      Anti-White

# %%
# Check for missing values 
df.isnull().sum()
# Out:
# incident_year                0
# state_abbr                   0
# state_name                   0
# region_name                  0
# incident_date                0
# offender_count               0
# offender_race               19
# victim_count                 0
# offense_type                 0
# total_individual_victims     0
# prejudice                    0
# dtype: int64

# %%
df['offender_race'].fillna('Unknown',inplace=True)

# %%
# checking again for missing values 
df.isnull().sum()
# Out:
# incident_year               0
# state_abbr                  0
# state_name                  0
# region_name                 0
# incident_date               0
# offender_count              0
# offender_race               0
# victim_count                0
# offense_type                0
# total_individual_victims    0
# prejudice                   0
# dtype: int64

# %%
# Checking for duplicates
dups = df.duplicated()

# %%
dups.shape
# Out:
# (199797,)

# %%
hate_crime_victim = df[(df['prejudice'] == 'Anti-Black or African American') 
         | (df['prejudice'] == 'Anti-Jewish') 
         | (df['prejudice'] == 'Anti-White') 
         | (df['prejudice'] == 'Anti-Gay (Male)') 
         | (df['prejudice'] == 'Anti-Hispanic or Latino') 
         | (df['prejudice'] == 'Anti-Other Race/Ethnicity/Ancestry') 
         | (df['prejudice'] == 'Anti-Lesbian, Gay, Bisexual, or Transgender (Mixed Group)') 
         | (df['prejudice'] == 'Anti-Asian') 
         | (df['prejudice'] == 'Anti-Lesbian (Female)') 
         | (df['prejudice'] == 'Anti-Islamic (Muslim)')
         | (df['prejudice'] == 'Anti-American Indian/Alaska Native')]

# %%
hate_crime_victim.head()
# Out:
#    incident_year state_abbr state_name region_name incident_date  \
# 0           1991         AR   Arkansas       South     31-AUG-91
# 1           1991         AR   Arkansas       South     19-SEP-91
# 2           1991         AR   Arkansas       South     04-JUL-91
# 3           1991         AR   Arkansas       South     24-DEC-91
# 4           1991         AR   Arkansas       South     23-DEC-91
#
#    offender_count              offender_race  victim_count  \
# 0               1                      White             1
# 1               1  Black or African American             1
# 2               1  Black or African American             1
# 3               1  Black or African American             2
# 4               1  Black or African American             1
#
#                                         offense_type  \
# 0                                       Intimidation
# 1                                     Simple Assault
# 2                                 Aggravated Assault
# 3  Aggravated Assault;Destruction/Damage/Vandalis...
# 4                                 Aggravated Assault
#
#    total_individual_victims                       prejudice
# 0                         1  Anti-Black or African American
# 1                         1                      Anti-White
# 2                         1  Anti-Black or African American
# 3                         1                      Anti-White
# 4                         1                      Anti-White

# %%
def nb_check(abbr):
    if abbr == 'NB':
        return 'NE'
    else:
        return abbr

# %%
by_state = hate_crime_victim
by_state['state_abbr'] = by_state['state_abbr'].apply(nb_check)

# %%
by_state[by_state['state_abbr']=='NE']
# Out:
#         incident_year state_abbr state_name region_name incident_date  \
# 38113            1996         NE   Nebraska     Midwest     04-APR-96
# 38114            1996         NE   Nebraska     Midwest     19-JUL-96
# 38115            1996         NE   Nebraska     Midwest     21-JUL-96
# 46476            1997         NE   Nebraska     Midwest     10-JUL-97
# 46477            1997         NE   Nebraska     Midwest     05-OCT-97
# ...               ...        ...        ...         ...           ...
# 196704           2018         NE   Nebraska     Midwest     23-AUG-18
# 196705           2018         NE   Nebraska     Midwest     08-AUG-18
# 196706           2018         NE   Nebraska     Midwest     03-DEC-18
# 196707           2018         NE   Nebraska     Midwest     20-APR-18
# 196711           2018         NE   Nebraska     Midwest     29-APR-18
#
#         offender_count              offender_race  victim_count  \
# 38113                1                      White             1
# 38114                1  Black or African American             1
# 38115                1  Black or African American             1
# 46476                0                    Unknown             1
# 46477                4                      White             4
# ...                ...                        ...           ...
# 196704               0                    Unknown             2
# 196705               0                    Unknown             1
# 196706               0                    Unknown             1
# 196707               0                    Unknown             2
# 196711               0                    Unknown             1
#
#                                      offense_type  total_individual_victims  \
# 38113                              Simple Assault                         1
# 38114                          Aggravated Assault                         1
# 38115                          Aggravated Assault                         1
# 46476    Destruction/Damage/Vandalism of Property                         1
# 46477                          Aggravated Assault                         4
# ...                                           ...                       ...
# 196704  Motor Vehicle Theft;Weapon Law Violations                         1
# 196705                  Drug Equipment Violations                         0
# 196706   Destruction/Damage/Vandalism of Property                         1
# 196707               Burglary/Breaking & Entering                         2
# 196711                             Simple Assault                         1
#
#                                  prejudice
# 38113              Anti-Hispanic or Latino
# 38114       Anti-Black or African American
# 38115       Anti-Black or African American
# 46476                          Anti-Jewish
# 46477   Anti-Other Race/Ethnicity/Ancestry
# ...                                    ...
# 196704                          Anti-White
# 196705                          Anti-White
# 196706                          Anti-White
# 196707                          Anti-White
# 196711                          Anti-White
#
# [868 rows x 11 columns]

# %%
hate_crime_victim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 180293 entries, 0 to 199795
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   incident_year             180293 non-null  int64
#  1   state_abbr                180293 non-null  object
#  2   state_name                180293 non-null  object
#  3   region_name               180293 non-null  object
#  4   incident_date             180293 non-null  object
#  5   offender_count            180293 non-null  int64
#  6   offender_race             180293 non-null  object
#  7   victim_count              180293 non-null  int64
#  8   offense_type              180293 non-null  object
#  9   total_individual_victims  180293 non-null  int64
#  10  prejudice                 180293 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 16.5+ MB

# %%
df['total_individual_victims'] = df['total_individual_victims'].astype(np.int64, errors='ignore')

# %%
hate_crime_victim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 180293 entries, 0 to 199795
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   incident_year             180293 non-null  int64
#  1   state_abbr                180293 non-null  object
#  2   state_name                180293 non-null  object
#  3   region_name               180293 non-null  object
#  4   incident_date             180293 non-null  object
#  5   offender_count            180293 non-null  int64
#  6   offender_race             180293 non-null  object
#  7   victim_count              180293 non-null  int64
#  8   offense_type              180293 non-null  object
#  9   total_individual_victims  180293 non-null  int64
#  10  prejudice                 180293 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 16.5+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199797 entries, 0 to 199796
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   incident_year             199797 non-null  int64
#  1   state_abbr                199797 non-null  object
#  2   state_name                199797 non-null  object
#  3   region_name               199797 non-null  object
#  4   incident_date             199797 non-null  object
#  5   offender_count            199797 non-null  int64
#  6   offender_race             199797 non-null  object
#  7   victim_count              199797 non-null  int64
#  8   offense_type              199797 non-null  object
#  9   total_individual_victims  199797 non-null  int64
#  10  prejudice                 199797 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 16.8+ MB

# %%
hate_crime_victim['incident_date'] = pd.to_datetime(hate_crime_victim['incident_date'])

# %%
hate_crime_victim.head()
# Out:
#    incident_year state_abbr state_name region_name incident_date  \
# 0           1991         AR   Arkansas       South    1991-08-31
# 1           1991         AR   Arkansas       South    1991-09-19
# 2           1991         AR   Arkansas       South    1991-07-04
# 3           1991         AR   Arkansas       South    1991-12-24
# 4           1991         AR   Arkansas       South    1991-12-23
#
#    offender_count              offender_race  victim_count  \
# 0               1                      White             1
# 1               1  Black or African American             1
# 2               1  Black or African American             1
# 3               1  Black or African American             2
# 4               1  Black or African American             1
#
#                                         offense_type  \
# 0                                       Intimidation
# 1                                     Simple Assault
# 2                                 Aggravated Assault
# 3  Aggravated Assault;Destruction/Damage/Vandalis...
# 4                                 Aggravated Assault
#
#    total_individual_victims                       prejudice
# 0                         1  Anti-Black or African American
# 1                         1                      Anti-White
# 2                         1  Anti-Black or African American
# 3                         1                      Anti-White
# 4                         1                      Anti-White

# %%
hate_crime_victim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 180293 entries, 0 to 199795
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   incident_year             180293 non-null  int64
#  1   state_abbr                180293 non-null  object
#  2   state_name                180293 non-null  object
#  3   region_name               180293 non-null  object
#  4   incident_date             180293 non-null  datetime64[ns]
#  5   offender_count            180293 non-null  int64
#  6   offender_race             180293 non-null  object
#  7   victim_count              180293 non-null  int64
#  8   offense_type              180293 non-null  object
#  9   total_individual_victims  180293 non-null  int64
#  10  prejudice                 180293 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(6)
# memory usage: 16.5+ MB

# %% [markdown]
# # 2. Wrangle Data

# %%
#create subset with only incident date and victim count
hate_crime_victims = hate_crime_victim[['incident_date', 'incident_year', 'victim_count']]

# %% [markdown]
# I chose the incident date and incident year along with the victim count to analyze the number of victims on each date and observe the trend in the number of victims over time.

# %%
#sort by year
hate_crime_victims=hate_crime_victims.sort_values(by='incident_date')

# %%
hate_crime_victims.head()
# Out:
#      incident_date  incident_year  victim_count
# 832     1991-01-01           1991             1
# 2199    1991-01-01           1991             1
# 4082    1991-01-01           1991             1
# 262     1991-01-01           1991             2
# 1152    1991-01-01           1991             2

# %%
hate_crime_victims.columns
# Out:
# Index(['incident_date', 'incident_year', 'victim_count'], dtype='object')

# %%
hate_crime_victims.set_index('incident_date')
# Out:
#                incident_year  victim_count
# incident_date
# 1991-01-01              1991             1
# 1991-01-01              1991             1
# 1991-01-01              1991             1
# 1991-01-01              1991             2
# 1991-01-01              1991             2
# ...                      ...           ...
# 2018-12-31              2018             1
# 2018-12-31              2018             1
# 2018-12-31              2018             1
# 2018-12-31              2018             1
# 2018-12-31              2018             1
#
# [180293 rows x 2 columns]

# %%
from datetime import datetime

hate_crime_victims['datetime'] = pd.to_datetime(hate_crime_victims['incident_date']) # Create a datetime column from "Date.""
hate_crime_victims = hate_crime_victims.set_index('datetime') # Set the datetime as the index of the dataframe.
hate_crime_victims.drop(['incident_date'], axis=1, inplace=True) # Drop the "Date" column.
hate_crime_victims.head()
# Out:
#             incident_year  victim_count
# datetime
# 1991-01-01           1991             1
# 1991-01-01           1991             1
# 1991-01-01           1991             1
# 1991-01-01           1991             2
# 1991-01-01           1991             2

# %%
hate_crime_victims_duplicates = hate_crime_victims[hate_crime_victims.duplicated()]

# %%
print(hate_crime_victims_duplicates)
# Out:
#             incident_year  victim_count
# datetime
# 1991-01-01           1991             1
# 1991-01-01           1991             1
# 1991-01-01           1991             2
# 1991-01-01           1991             1
# 1991-01-01           1991             1
# ...                   ...           ...
# 2018-12-31           2018             1
# 2018-12-31           2018             1
# 2018-12-31           2018             1
# 2018-12-31           2018             1
# 2018-12-31           2018             1
#
# [179903 rows x 2 columns]

# %%
hate_crime_victims_clean = hate_crime_victims.drop_duplicates()

# %%
hate_crime_victims_clean.head()
# Out:
#             incident_year  victim_count
# datetime
# 1991-01-01           1991             1
# 1991-01-01           1991             2
# 1991-01-05           1991             3
# 1991-01-18           1991             4
# 1991-01-23           1991             6

# %%
hate_crime_victims_clean['total_victims'] = hate_crime_victims_clean.groupby('datetime')['victim_count'].transform('sum')

# %%
hate_crime_victims_clean.head()
# Out:
#             incident_year  victim_count  total_victims
# datetime
# 1991-01-01           1991             1              3
# 1991-01-01           1991             2              3
# 1991-01-05           1991             3              3
# 1991-01-18           1991             4              4
# 1991-01-23           1991             6              6

# %%
hate_crime_victims_clean=hate_crime_victims_clean.drop(columns=['incident_year','victim_count'])

# %%
hate_crime_victims_clean.head()
# Out:
#             total_victims
# datetime
# 1991-01-01              3
# 1991-01-01              3
# 1991-01-05              3
# 1991-01-18              4
# 1991-01-23              6

# %%
#Plot total_crime over time
plt.figure(figsize=(15,5), dpi=100)
plt.plot(hate_crime_victims_clean)

# %%
hate_crime_victims_clean.columns
# Out:
# Index(['total_victims'], dtype='object')

# %%
hate_crime_victims_clean.reset_index(inplace=True)

# %%
hate_crime_victims_clean.columns
# Out:
# Index(['datetime', 'total_victims'], dtype='object')

# %%
hate_crime_victims_clean.set_index('datetime',inplace=True)

# %%
hate_crime_victims_clean.index=pd.to_datetime(hate_crime_victims_clean.index)

# %%
hate_crime_victims_clean.dropna(inplace=True)
hate_crime_victims_clean.plot()
# Out:
# <Axes: xlabel='datetime'>

# %% [markdown]
# # 3. Time Series Analysis

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
result=seasonal_decompose(hate_crime_victims_clean['total_victims'], model='additive', period=28)

# %%
result.seasonal.plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
result.trend.plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
result.plot()

# %% [markdown]
# The first chart in the figure above represents the raw data, referred to as the level. This data exhibits fluctuations with both decreases and increases in the count of total hate crime victims. The third component is seasonality, which shows a pattern similar to the level plot. It is also observed that around the end or beginning of a presidential term, there tends to be an increase in the number of hate crime victims. There is minimal unexplained noise in the data. While a few outliers exist, overall, the data is quite smooth and clusters closely around the trend line.

# %% [markdown]
# # Testing for Stationarity

# %%
# The adfuller() function will import from the model from statsmodels for the test; however, running it will only return 
# an array of numbers. This is why you need to also define a function that prints the correct output from that array.

from statsmodels.tsa.stattools import adfuller # Import the adfuller() function

def dickey_fuller(timeseries): # Define the function
    # Perform the Dickey-Fuller test:
    print ('Dickey-Fuller Stationarity test:')
    test = adfuller(timeseries, autolag='AIC')
    result = pd.Series(test[0:4], index=['Test Statistic','p-value','Number of Lags Used','Number of Observations Used'])
    for key,value in test[4].items():
       result['Critical Value (%s)'%key] = value
    print (result)

# Apply the test using the function on the time series
dickey_fuller(hate_crime_victims_clean['total_victims'])
# Out:
# Dickey-Fuller Stationarity test:
# Test Statistic                -1.777069e+01
# p-value                        3.308484e-30
# Number of Lags Used            0.000000e+00
# Number of Observations Used    3.890000e+02
# Critical Value (1%)           -3.447273e+00
# Critical Value (5%)           -2.868999e+00
# Critical Value (10%)          -2.570743e+00
# dtype: float64

# %% [markdown]
# The test statistic is significantly smaller than the critical value at a 90% confidence interval, leading us to reject the null hypothesis. Therefore, there is evidence of a unit root, indicating that the data is stationary.

# %%
# Check out a plot of autocorrelations

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf # Here, you import the autocorrelation and partial correlation plots

plot_acf(hate_crime_victims_clean)
plt.show()
